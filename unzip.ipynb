# %%
import random
x = [1,2,3,4]
random.Random(4).shuffle(x)
print(x)
# Out:
# [3, 1, 4, 2]

# %%
x = [1,2,3,4]
random.Random(4).shuffle(x)
print(x)
# Out:
# [3, 1, 4, 2]

# %%
import glob
paths = glob.glob("/content/drive/Shareddrives/AML_Project/data_Y/*.jpg")

# %%
len(paths)
# Out:
# 0

# %%
# !ls -l /content/drive/Shareddrives/AML_Project/data_Y | egrep -c '^-'
# Out:
# 5734

# %%
# !rm -rf /content/drive/Shareddrives/AML_Project/data_Y

# %%
drive.flush_and_unmount()

# %%
import glob
paths = glob.glob("/content/drive/Shareddrives/AML_Project/data_Y/*.jpg")

# %%
len(paths)
# Out:
# 5734

# %%
paths[-1]
# Out:
# '/content/data_Y/Images/boris-kustodiev_177.jpg'

# %%
# !rm -rf /content/drive/Shareddrives/AML_Project/data_Y

# %%
# !cp -r /content/data_Y/Images /content/drive/Shareddrives/AML_Project/data_Y

# %%
# !mv /content/drive/Shareddrives/AML_Project/Images /content/drive/Shareddrives/AML_Project/data_Y

# %%
# !unzip /content/drive/Shareddrives/AML_Project/portraits.zip -d /content/drive/Shareddrives/AML_Project
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/Shareddrives/AML_Project/Images/boris-kustodiev_201.jpg
#   inflating: /content/drive/Shareddrives/AML_Project/Images/boris-kustodiev_202.jpg
#   inflating: /content/drive/Shareddrives/AML_Project/Images/boris-kustodiev_203.jpg
#   inflating: /content/drive/Shareddrives/AML_Project/Images/boris-kustodiev_204.jpg
#   inflating: /content/drive/Shareddrives/AML_Project/Images/boris-kustodiev_205.jpg
#   inflating: /content/drive/Shareddrives/AML_Project/Images/boris-kustodiev_206.jpg
#   inflating: /content/drive/Shareddrives/AML_Project/Images/boris-kustodiev_207.jpg
#   inflating: /content/drive/Shareddrives/AML_Project/Images/boris-kustodiev_208.jpg
#   inflating: /content/drive/Shareddrives/AML_Project/Images/boris-kustodiev_209.jpg
#   inflating: /content/drive/Shareddrives/AML_Project/Images/boris-kustodiev_21.jpg
#   inflating: /content/drive/Shareddrives/AML_Project/Images/boris-kustodiev_210.jpg
# ...

# %%
drive.flush_and_unmount()

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/Shareddrives/AML_Project/photos.zip -d /content/drive/Shareddrives/AML_Project/photos
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/Shareddrives/AML_Project/photos/Humans/1 (2910).jpg
#   inflating: /content/drive/Shareddrives/AML_Project/photos/Humans/1 (2911).jpg
#   inflating: /content/drive/Shareddrives/AML_Project/photos/Humans/1 (2912).jpg
#   inflating: /content/drive/Shareddrives/AML_Project/photos/Humans/1 (2913).jpg
#   inflating: /content/drive/Shareddrives/AML_Project/photos/Humans/1 (2914).jpg
#   inflating: /content/drive/Shareddrives/AML_Project/photos/Humans/1 (2915).jpg
#   inflating: /content/drive/Shareddrives/AML_Project/photos/Humans/1 (2916).jpg
#   inflating: /content/drive/Shareddrives/AML_Project/photos/Humans/1 (2917).jpg
#   inflating: /content/drive/Shareddrives/AML_Project/photos/Humans/1 (2918).jpg
#   inflating: /content/drive/Shareddrives/AML_Project/photos/Humans/1 (2919).jpg
#   inflating: /content/drive/Shareddrives/AML_Project/photos/Humans/1 (292).jpg
# ...

# %%
# !unzip /content/drive/Shareddrives/AML_Project/portraits.zip -d /content/drive/Shareddrives/AML_Project/portraits
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/Shareddrives/AML_Project/portraits/Images/boris-kustodiev_201.jpg
#   inflating: /content/drive/Shareddrives/AML_Project/portraits/Images/boris-kustodiev_202.jpg
#   inflating: /content/drive/Shareddrives/AML_Project/portraits/Images/boris-kustodiev_203.jpg
#   inflating: /content/drive/Shareddrives/AML_Project/portraits/Images/boris-kustodiev_204.jpg
#   inflating: /content/drive/Shareddrives/AML_Project/portraits/Images/boris-kustodiev_205.jpg
#   inflating: /content/drive/Shareddrives/AML_Project/portraits/Images/boris-kustodiev_206.jpg
#   inflating: /content/drive/Shareddrives/AML_Project/portraits/Images/boris-kustodiev_207.jpg
#   inflating: /content/drive/Shareddrives/AML_Project/portraits/Images/boris-kustodiev_208.jpg
#   inflating: /content/drive/Shareddrives/AML_Project/portraits/Images/boris-kustodiev_209.jpg
# ...
